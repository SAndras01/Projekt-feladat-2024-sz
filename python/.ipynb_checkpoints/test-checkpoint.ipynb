# %% [markdown]
# # Example

# %% [markdown]
# ## Includes

# %%
from measStation import MeasStation
import time
import pandas as pd

# %% [markdown]
# ## Initialization

# %%
myStation = MeasStation()
#myStation.initStorage()
# Out:
# searching for device...
# 	 in COM9:
# 		found

# %% [markdown]
# ## Measurement

# %%
myStation.setMeasFreq(60)
#myStation.initStorage()
print(myStation.enterMeasMode())
# Out:
# True

# %%
time.sleep(10)

# %%
print(myStation.enterCommMode())

# %% [markdown]
# ## Data acquisition and plotting

# %%
myDF = myStation.readoutStorage()
myDF.plot(x = "Time", y = "Value")
myStation.enterMeasMode()
# Out:
# ...
# Loading...: 100%|██████████| 478/478 [00:09<00:00, 50.19it/s]
# True

# %%
import openpyxl
myDF['Time'] = myDF['Time'].dt.tz_localize(None)
myDF.to_excel("11_16_1721_11_16_0109_60s.xlsx")
